# %%
# !python -m generate_instruction generate_instruction_following_data \
  --output_dir="./" \
  --num_instructions_to_generate=50 \
  --model_name="gpt-3.5-turbo-16k" \
  --similarity_threshold=1
# Out:
# Loaded 9 human-written seed instructions
# Loaded 32 machine-generated instructions
#   0%|                                                    | 0/50 [00:00<?, ?it/s]raw_instructions >>
#  ['4. Instruction:Perform a code review on the provided Java code file and identify any issues related to the given factors (readability, uniformity, understandability, correctness, performance, and security).\n4. Input:\n```\nimport java.util.ArrayList;\nimport java.util.List;\n\npublic class User {\n    private String name;\n    private int age;\n\n    public User(String name, int age) {\n        this.name = name;\n        this.age = age;\n    }\n\n    public String getName() {\n        return name;\n    }\n\n    public int getAge() {\n        return age;\n    }\n\n    public List<User> getUsersWithSameAge(List<User> users) {\n        List<User> result = new ArrayList<>();\n\n        for (User user : users) {\n            if (user.getAge() == this.age) {\n                result.add(user);\n            }\n        }\n\n        return result;\n    }\n\n    public void printUserDetails() {\n        System.out.println("Name: " + name);\n        System.out.println("Age: " + age);\n    }\n}\n```\n4. Output:\n- Readability (Status: POSITIVE)\n  - Variable names are clear and descriptive.\n  - The code is properly indented and includes whitespace for better readability.\n- Uniformity (Status: POSITIVE)\n  - Consistent use of brackets for code blocks.\n  - Consistent use of whitespace around operators and after commas.\n  - Consistent naming convention with camel case used for method and variable names.\n- Understandability (Status: POSITIVE)\n  - The code is well-structured and easy to follow.\n  - Method and variable names are self-explanatory and descriptive of their purpose.\n- Correctness (Status: POSITIVE)\n  - The code appears to be correct.\n- Performance (Status: POSITIVE)\n  - No obvious performance issues identified.\n- Security (Status: POSITIVE)\n  - No security issues identified.\n', '\n5. Instruction: Perform a code review on the provided C# code file and improve the code in terms of readability, uniformity, understandability, correctness, performance, and security.\n5. Input:\n```\nusing System;\n\npublic class Program\n{\n    public static void Main()\n    {\n        int number = 5;\n\n        if (number % 2 == 0)\n            Console.WriteLine("Even number");\n        else\n            Console.WriteLine("Odd number");\n\n        for (int i = 1; i <= 10; i++)\n        {\n            if (i % 2 == 0)\n                Console.WriteLine(i);\n        }\n    }\n}\n```\n5. Output:\n- Readability (Status: POSITIVE)\n  - The code is properly indented, making it easily readable.\n  - The variable name `number` is descriptive and understandable.\n- Uniformity (Status: POSITIVE)\n  - Consistent use of braces for code blocks, even for single-line statements.\n- Understandability (Status: POSITIVE)\n  - The code is concise and easy to understand.\n  - The logic behind determining even and odd numbers is clear.\n- Correctness (Status: POSITIVE)\n  - The code appears to be correct.\n- Performance (Status: POSITIVE)\n  - No performance issues identified.\n- Security (Status: POSITIVE)\n  - No security issues identified.\n', '\n6. Instruction: Perform a code review on the provided PHP code file and identify any issues related to the given factors (readability, uniformity, understandability, correctness, performance, and security).\n6. Input:\n```\n<?php\n\nfunction multiply_numbers($a, $b)\n{\n    $product = $a * $b;\n\n    return $product;\n}\n\nfunction divide_numbers($a, $b)\n{\n    if ($b != 0)\n        $quotient = $a / $b;\n        return $quotient;\n    else\n        echo "Error: Cannot divide by zero";\n}\n\nfunction add_numbers($a, $b)\n{\n    return $a + $b;\n}\n\n$x = 5;\n$y = 2;\n\n$result1 = multiply_numbers($x, $y);\necho "Product: " . $result1;\n\n$result2 = divide_numbers($x, $y);\necho "Quotient: " . $result2;\n\n$result3 = add_numbers($x, $y);\necho "Sum: " . $result3;\n\n?>\n```\n6. Output:\n- Readability (Status: NEGATIVE)\n  - Inconsistent placement of curly braces for code blocks.\n  - Inconsistent capitalization o ...
# Skipping due to condition #2.
#  78%|█████████████████████████████████▌         | 39/50 [02:08<01:15,  6.86s/it]Request 1 took 30.80s, processing took 97.38s
# Generated 7 instructions, kept 7 instructions
#  92%|███████████████████████████████████████▌   | 46/50 [04:20<00:52, 13.10s/it]Request 2 took 40.62s, processing took 91.51s
# Generated 7 instructions, kept 7 instructions
# 53it [06:17, 13.17s/it]Request 3 took 34.47s, processing took 82.27s
# Generated 7 instructions, kept 7 instructions
# 53it [06:17,  7.11s/it]
